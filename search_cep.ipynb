# %% [markdown]
# Este script em Python faz a consulta de vários CEP no site dos Correios e depois coloca as informações em um arquivo xlsx.

# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pyautogui as pg
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/mouseinfo/__init__.py:276
#     275 try:
# --> 276     import tkinter
#     277     from tkinter import ttk
#
# ModuleNotFoundError: No module named 'tkinter'
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[7], line 4
#       3 from selenium.webdriver.common.by import By
# ----> 4 import pyautogui as pg
#
# File ~/.local/lib/python3.8/site-packages/pyautogui/__init__.py:249
#     248 try:
# --> 249     import mouseinfo
#     251     def mouseInfo():
#
# File ~/.local/lib/python3.8/site-packages/mouseinfo/__init__.py:280
#     279         except ImportError:
# ...

# %%
browser = wb.Chrome()
browser.get('https://buscacepinter.correios.com.br/app/endereco/index.php')

browser.find_element(By.NAME, 'endereco').send_keys('ola mundo')
print(' ')
